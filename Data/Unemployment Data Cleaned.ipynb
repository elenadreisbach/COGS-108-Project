# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pickle

# %%
#Groupby not working for years 2005/2006

# %%
df_2005 = pd.read_excel('unemployment_2005.xlsx', skiprows=5)
df_2005.drop(['Unnamed: 0' , 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 5'], axis = 1, inplace=True)
df_2005.columns = ['State', 'Year', 'Labor Force', 'Employed', 'Unemployed', 'Unemployment Rate (%)']
df_2005['State']=df_2005['State'].str[-2:]
df_2005 = df_2005.set_index(['State'])
#df_2005=df_2005.groupby(df_2005.index).sum()
#df_2005['Unemployment Rate (%)'] = df_2005['Labor Force'] / df_2005['Unemployed'] 
#df_2005['Year']=2005
#df_2005=df_2005[:-1]
#df_2005

# %%
df_2006 = pd.read_excel('unemployment_2006.xlsx', skiprows=5)
df_2006.drop(['Unnamed: 0' , 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 5'], axis = 1, inplace=True)
df_2006.columns = ['State', 'Year', 'Labor Force', 'Employed', 'Unemployed', 'Unemployment Rate (%)']
df_2006['State']=df_2006['State'].str[-2:]
df_2006 = df_2006.set_index(['State'])
#df_2006=df_2006.groupby(df_2006.index).sum()
#df_2006['Unemployment Rate (%)'] = df_2006['Labor Force'] / df_2006['Unemployed'] 
df_2006['Year']=2006
df_2006=df_2006[:-1]
df_2006.shape
# Out:
# (3219, 5)

# %%
df_2007 = pd.read_excel('unemployment_2007.xlsx', skiprows=5)
df_2007.drop(['Unnamed: 0' , 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 5'], axis = 1, inplace=True)
df_2007.columns = ['State', 'Year', 'Labor Force', 'Employed', 'Unemployed', 'Unemployment Rate (%)']
df_2007['State']=df_2007['State'].str[-2:]
df_2007 = df_2007.set_index(['State'])
df_2007=df_2007.groupby(df_2007.index).sum()
df_2007['Unemployment Rate (%)'] = df_2007['Labor Force'] / df_2007['Unemployed'] 
df_2007['Year']=2007
df_2007=df_2007[:-1]
df_2007
# Out:
#        Year  Labor Force    Employed  Unemployed  Unemployment Rate (%)
# State
# AK     2007     350786.0    328579.0     22207.0              15.796190
# AL     2007    2175614.0   2089131.0     86483.0              25.156551
# AR     2007    1369289.0   1296573.0     72716.0              18.830642
# AZ     2007    3034015.0   2917116.0    116899.0              25.954157
# CA     2007   17893090.0  16931594.0    961496.0              18.609635
# CO     2007    2664682.0   2565220.0     99462.0              26.790955
# CT     2007    1856200.0   1773156.0     83044.0              22.352006
# DE     2007     443573.0    428312.0     15261.0              29.065789
# FL     2007    9157134.0   8789775.0    367359.0              24.926935
# GA     2007    4815821.0   4597638.0    218183.0              22.072393
# HI     2007     638395.0    620535.0     17860.0              35.744401
# IA     2007    1660676.0   1599332.0     61344.0              27.071531
# ...

# %%
df_2008 = pd.read_excel('unemployment_2008.xlsx', skiprows=5)
df_2008.drop(['Unnamed: 0' , 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 5'], axis = 1, inplace=True)
df_2008.columns = ['State', 'Year', 'Labor Force', 'Employed', 'Unemployed', 'Unemployment Rate (%)']
df_2008['State']=df_2008['State'].str[-2:]
df_2008 = df_2008.set_index(['State'])
df_2008=df_2008.groupby(df_2008.index).sum()
df_2008['Unemployment Rate (%)'] = df_2008['Labor Force'] / df_2008['Unemployed'] 
df_2008['Year']=2008
df_2008=df_2008[:-1]

# %%
df_2009 = pd.read_excel('unemployment_2009.xlsx', skiprows=5)
df_2009.drop(['Unnamed: 0' , 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 5'], axis = 1, inplace=True)
df_2009.columns = ['State', 'Year', 'Labor Force', 'Employed', 'Unemployed', 'Unemployment Rate (%)']
df_2009['State']=df_2009['State'].str[-2:]
df_2009 = df_2009.set_index(['State'])

# %%
df_2009=df_2009.groupby(df_2009.index).sum()
df_2009['Unemployment Rate (%)'] = df_2009['Labor Force'] / df_2009['Unemployed'] 
df_2009['Year']=2009
df_2009=df_2009[:-1]

# %%
#df_2009

# %%
df_2010 = pd.read_excel('unemployment_2010.xlsx', skiprows=5)
df_2010.drop(['Unnamed: 0' , 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 5'], axis = 1, inplace=True)
df_2010.columns = ['State', 'Year', 'Labor Force', 'Employed', 'Unemployed', 'Unemployment Rate (%)']
df_2010['State']=df_2010['State'].str[-2:]
df_2010 = df_2010.set_index(['State'])
df_2010=df_2010.groupby(df_2010.index).sum()
df_2010['Unemployment Rate (%)'] = df_2010['Labor Force'] / df_2010['Unemployed'] 
df_2010['Year']=2010
df_2010=df_2010[:-1]

# %%
#df_2010

# %%
df_2011 = pd.read_excel('unemployment_2011.xlsx', skiprows=5)
df_2011.drop(['Unnamed: 0' , 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 5'], axis = 1, inplace=True)
df_2011.columns = ['State', 'Year', 'Labor Force', 'Employed', 'Unemployed', 'Unemployment Rate (%)']
df_2011['State']=df_2011['State'].str[-2:]
df_2011 = df_2011.set_index(['State'])
df_2011=df_2011.groupby(df_2011.index).sum()
df_2011['Unemployment Rate (%)'] = df_2011['Labor Force'] / df_2011['Unemployed'] 
df_2011['Year']=2011
df_2011=df_2011[:-1]

# %%
#df_2011

# %%
df_unemployment_by_state=pd.concat([df_2007, df_2008, df_2009, df_2010, df_2011], axis=1)
df_unemployment_by_state.to_json('Clean_Data/df_unemployment_by_state.json', orient='values')

# %%
df_unemployment_by_state
# Out:
#        Year  Labor Force    Employed  Unemployed  Unemployment Rate (%)  Year  \
# State
# AK     2007     350786.0    328579.0     22207.0              15.796190  2008
# AL     2007    2175614.0   2089131.0     86483.0              25.156551  2008
# AR     2007    1369289.0   1296573.0     72716.0              18.830642  2008
# AZ     2007    3034015.0   2917116.0    116899.0              25.954157  2008
# CA     2007   17893090.0  16931594.0    961496.0              18.609635  2008
# CO     2007    2664682.0   2565220.0     99462.0              26.790955  2008
# CT     2007    1856200.0   1773156.0     83044.0              22.352006  2008
# DE     2007     443573.0    428312.0     15261.0              29.065789  2008
# FL     2007    9157134.0   8789775.0    367359.0              24.926935  2008
# GA     2007    4815821.0   4597638.0    218183.0              22.072393  2008
# HI     2007     638395.0    620535.0     17860.0              35.744401  2008
# ...
